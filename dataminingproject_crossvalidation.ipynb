# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from scipy.spatial import distance
from sklearn import cluster

file =r"C:\Users\amitn\Desktop\ms data science\Data mining\seeds_dataset.txt"
df_all = pd.read_csv(file, delim_whitespace = True, header=None, names =["Area","Perimeter","compactness","Len_kernel","width_Kernel","asymetry_coef","Len_groove","class"])
df=pd.DataFrame({"Area":df_all.values[:,0],"Perimeter": df_all.values[:,1],"compactness":df_all.values[:,2],"Len_kernel": df_all.values[:,3],"width_Kernel" :df_all.values[:,4],"asymetry_coef" :df_all.values[:,5],"Len_groove":df_all.values[:,6]})

# %%
class1=df_all.values[:70,7]-labels1[:70]
np.unique(class1,return_counts=True)
# Out:
# (array([-1.,  0.,  1.]), array([60,  1,  9], dtype=int64))

# %%
class2=df_all.values[70:140,7]-labels1[70:140]
np.unique(class2,return_counts=True)
# Out:
# (array([ 1.,  2.]), array([10, 60], dtype=int64))

# %%
class3=df_all.values[140:,7]-labels1[140:]
np.unique(class3,return_counts=True)
# Out:
# (array([ 1.,  2.]), array([68,  2], dtype=int64))

# %%
import random
data =np.arange(0,210,1)
random.shuffle(data)
data
# Out:
# array([181,  93,  46,  17, 201, 198,  60, 199,  29, 166, 140, 116, 194,
#         97, 115, 124, 171, 130,  28, 193,  58,  34, 108,   9, 135, 173,
#         52,   8, 168, 165, 167,  87,  41, 106, 176, 152, 185,  16, 127,
#        138, 110, 122, 202,  32,   4, 107, 143, 209, 184, 105,  67,  39,
#        178, 139,   5,  26, 182,  96, 157,  19,  64,  22, 125,  55, 136,
#         43,   2, 120, 159,   7, 161, 129,  79,  65, 111,  59,  51, 146,
#        134,  13, 144,  57, 192,  78,  75,  88, 204,  40,  11,   3,  36,
#        132,  94, 128,  12, 197,  72, 102,  53,  24, 170, 163, 137,  95,
#        155, 150, 126,  42,  44, 113,  68, 205, 183,  74,  30, 148,  90,
#        123,  25,   0, 131, 191,  33, 103,  20,  31,  18,  99,  98, 104,
#        158, 118,  66,  92,   1, 208, 186,  10,  49, 175,  47,  63,  81,
#        114,  56, 174, 160,  69, 149,  76, 119,  61,  21, 164,  83,  84,
#        145, 109,  73, 179, 180, 187,  48,  27,  37,  85, 112, 189,  89,
# ...

# %%
shuffled_data=np.zeros((210,8))

# %%
for i in range(0,210):
    shuffled_data[i]=df_all.values[data[i]]

# %%
# divide in 5 sample
data_1=np.zeros((168,8))
for i in range(0,168):
    data_1[i]= shuffled_data[i]

# %%
kmeans=KMeans(n_clusters=3).fit(data_1[:,:7])
centers=np.asarray(kmeans.cluster_centers_,dtype=np.uint8)
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )  
LABEL_COLOR_MAP = {0 : 'r',1 : 'k', 2 : 'b'}
label_color = [LABEL_COLOR_MAP[l] for l in labels]
#b=plt.scatter(df.values[:,0], df.values[:,1], c=label_color)
centers
# Out:
# array([[11, 13,  0,  5,  2,  4,  5],
#        [18, 16,  0,  6,  3,  3,  6],
#        [14, 14,  0,  5,  3,  2,  5]], dtype=uint8)

# %%
data_2=np.zeros((168,8))
for i in range(0,168):
    j=i+42
    data_2[i]= shuffled_data[j]

# %%
kmeans=KMeans(n_clusters=3).fit(data_2[:,:7])
centers=np.asarray(kmeans.cluster_centers_,dtype=np.uint8)
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )  
LABEL_COLOR_MAP = {0 : 'r',1 : 'k', 2 : 'b'}
label_color = [LABEL_COLOR_MAP[l] for l in labels]
#b=plt.scatter(df.values[:,0], df.values[:,1], c=label_color)
centers
# Out:
# array([[11, 13,  0,  5,  2,  4,  5],
#        [18, 16,  0,  6,  3,  3,  6],
#        [14, 14,  0,  5,  3,  2,  5]], dtype=uint8)

# %%
data_3=np.zeros((168,8))
for i in range(0,84):
    
    data_3[i]= shuffled_data[i]
j=84    
for i in range(126,210):
    data_3[j]=shuffled_data[i]
    j=j+1
data_3[165:]
# Out:
# array([[ 20.71  ,  17.23  ,   0.8763,   6.579 ,   3.814 ,   4.451 ,
#           6.451 ,   2.    ],
#        [ 11.18  ,  13.04  ,   0.8266,   5.22  ,   2.693 ,   3.332 ,
#           5.001 ,   3.    ],
#        [ 11.24  ,  13.    ,   0.8359,   5.09  ,   2.715 ,   3.521 ,
#           5.088 ,   3.    ]])

# %%
kmeans=KMeans(n_clusters=3).fit(data_3[:,:7])
centers=np.asarray(kmeans.cluster_centers_,dtype=np.uint8)
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )  
LABEL_COLOR_MAP = {0 : 'r',1 : 'k', 2 : 'b'}
label_color = [LABEL_COLOR_MAP[l] for l in labels]
#b=plt.scatter(df.values[:,0], df.values[:,1], c=label_color)
centers
# Out:
# array([[11, 13,  0,  5,  2,  4,  5],
#        [18, 16,  0,  6,  3,  3,  6],
#        [14, 14,  0,  5,  3,  2,  5]], dtype=uint8)

# %%
data_4=np.zeros((168,8))
for i in range(0,126):
    
    data_4[i]= shuffled_data[i]
j=126    
for i in range(168,210):
    data_4[j]=shuffled_data[i]
    j=j+1

# %%
kmeans=KMeans(n_clusters=3).fit(data_4[:,:7])
centers=np.asarray(kmeans.cluster_centers_,dtype=np.uint8)
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )  
LABEL_COLOR_MAP = {0 : 'r',1 : 'k', 2 : 'b'}
label_color = [LABEL_COLOR_MAP[l] for l in labels]
#b=plt.scatter(df.values[:,0], df.values[:,1], c=label_color)
centers
# Out:
# array([[14, 14,  0,  5,  3,  2,  5],
#        [18, 16,  0,  6,  3,  3,  6],
#        [12, 13,  0,  5,  2,  4,  5]], dtype=uint8)

# %%
data_5=np.zeros((168,8))
for i in range(0,42):
    
    data_5[i]= shuffled_data[i]
j=42
for i in range(84,210):
    data_5[j]=shuffled_data[i]
    j=j+1

kmeans=KMeans(n_clusters=3).fit(data_5[:,:7])
centers=np.asarray(kmeans.cluster_centers_,dtype=np.uint8)
labels = np.asarray(kmeans.labels_,dtype=np.uint8 )  
LABEL_COLOR_MAP = {0 : 'r',1 : 'k', 2 : 'b'}
label_color = [LABEL_COLOR_MAP[l] for l in labels]
#b=plt.scatter(df.values[:,0], df.values[:,1], c=label_color)
centers
labels[labels==2]=0
#c3=data_5[:,7]-labels
#np.unique(c3,return_counts=True)
# Out:
# array([[14, 14,  0,  5,  3,  2,  5],
#        [18, 16,  0,  6,  3,  3,  6],
#        [11, 13,  0,  5,  2,  4,  5]], dtype=uint8)

# %%
from sklearn.metrics.pairwise import euclidean_distances
c=np.zeros((3,7))
c=[[14, 14,  0,  5,  3,  2,  5],
       [18, 16,  0,  6,  3,  3,  6],
       [11, 13,  0,  5,  2,  4,  5]]
c=np.asarray(c) 
labels=np.zeros(210)
name=[1,2,3]
dist=np.zeros((210,3))
name=np.asarray(name)
n=0
#for j in range(0,3):
 #   dist[:,j]=euclidean_distances(df.values,c[j])
df.values[1]    
for i in range(0,210):
    dist[i][0]=euclidean_distances([df_all.values[i,:7]],[c[0]])
    dist[i][1]=euclidean_distances([df_all.values[i,:7]],[c[1]])
    dist[i][2]=euclidean_distances([df_all.values[i,:7]],[c[2]])    
    labels[i]=1+np.argmin(dist[i])

# %%
c2=labels[:70]-df_all.values[:70,7]
np.unique(c2,return_counts=True)
c2=labels[70:140]-df_all.values[70:140,7]
np.unique(c2,return_counts=True)
c3=labels[140:]-df_all.values[140:,7]
np.unique(c3,return_counts=True)
c=labels-df_all.values[:,7]
np.count_nonzero(c)
miscluster=np.zeros((24,7))
misclus=np.nonzero(c)

misclus=np.asarray(misclus)
for i in range(24):
    k=misclus[0][i]
    miscluster[i]=df_all.values[k,:7]
# Out:
# (array([ 0.,  1.,  2.]), array([58,  7,  5], dtype=int64))

# %%
c2=labels[70:140]-df_all.values[70:140,7]
np.unique(c2,return_counts=True)
# Out:
# (array([-1.,  0.]), array([ 4, 66], dtype=int64))

# %%
c3=labels[140:]-df_all.values[140:,7]
np.unique(c3,return_counts=True)
# Out:
# (array([-2.,  0.]), array([ 8, 62], dtype=int64))

# %%
c=labels-df_all.values[:,7]

# %%
np.count_nonzero(c)
# Out:
# 24

# %%
miscluster=np.zeros((24,7))
misclus=np.nonzero(c)

misclus=np.asarray(misclus)
for i in range(24):
    k=misclus[0][i]
    miscluster[i]=df_all.values[k,:7]

# %%
# Out:
# array([[  8,   9,  19,  35,  36,  37,  39,  43,  51,  60,  61,  62, 132,
#         135, 137, 138, 148, 160, 165, 179, 197, 198, 199, 201]], dtype=int64)

# %%
label_color = [LABEL_COLOR_MAP[l] for l in labels1]
b=plt.scatter(df_all.values[:,0], df_all.values[:,1], c=label_color)
b=plt.scatter(miscluster[:,0], miscluster[:,1], c='green')

# %%
plt.show(b)

# %%
label_color = [LABEL_COLOR_MAP[l] for l in labels1]
b=plt.scatter(df_all.values[:,3], df_all.values[:,2], c=label_color)
b=plt.scatter(miscluster[:,3], miscluster[:,2], c='green')

# %%
plt.show(b)

# %%
fig=plt.figure()
axis0 =fig.add_subplot(4,2,1)
axis0=plt.scatter(df_all.values[:,0], df_all.values[:,1], c=label_color,marker='.')
axis0=plt.scatter(miscluster[:,0], miscluster[:,1], c='green',marker='.')
axis1 =fig.add_subplot(4,2,2)
axis1=plt.scatter(df_all.values[:,0], df_all.values[:,2], c=label_color,marker='.')
axis1=plt.scatter(miscluster[:,0], miscluster[:,2], c='green',marker='.')
axis2 =fig.add_subplot(4,2,3)
axis2=plt.scatter(df_all.values[:,0], df_all.values[:,3], c=label_color,marker='.')
axis2=plt.scatter(miscluster[:,0], miscluster[:,3], c='green',marker='.')

# %%
plt.show()
axis0.set_xlabel('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-332-363f1f74bc5c> in <module>()
#       1 plt.show()
# ----> 2 axis0.set_xlabel('a')
#
# AttributeError: 'PathCollection' object has no attribute 'set_xlabel'

# %%
fig, ax = plt.subplots()

ax.set_title("Cluster",fontsize=14)
ax.set_xlabel("area",fontsize=12)
ax.set_ylabel("compactness",fontsize=12)
ax.grid(True,linestyle='-',color='0.75')
ax=plt.scatter(df_all.values[:,0], df_all.values[:,2], c=label_color,marker='.')
ax=plt.scatter(miscluster[:,0], miscluster[:,2], c='green',marker='.')
plt.show()
axis2=plt.scatter(df_all.values[:,0], df_all.values[:,3], c=label_color,marker='.')
ax=plt.scatter(miscluster[:,0], miscluster[:,3], c='green',marker='.')

# %%
plt.subplot(2, 1, 1)
plt.scatter(df_all.values[:,0], df_all.values[:,2], c=label_color,marker='.')
plt.scatter(miscluster[:,0], miscluster[:,2], c='green',marker='.')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
plt.grid(True,linestyle='-',color='0.75')

plt.subplot(2, 1, 2)
plt.scatter(df_all.values[:,0], df_all.values[:,3], c=label_color,marker='.')
plt.scatter(miscluster[:,0], miscluster[:,3], c='green',marker='.')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
plt.grid(True,linestyle='-',color='0.75')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets

# import some data to play with
iris = datasets.load_iris()
X = df_all.values[:, 4:6]  # we only take the first two features.
Y = df_all.values[:,7]

h = .02  # step size in the mesh

logreg = linear_model.LogisticRegression(C=1e5)

# we create an instance of Neighbours Classifier and fit the data.
logreg.fit(X, Y)

# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = logreg.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure(1, figsize=(4, 3))
plt.pcolormesh(xx, yy, Z, cmap=plt.cm.Paired)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=Y, edgecolors='k', cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xticks(())
plt.yticks(())


plt.show()
